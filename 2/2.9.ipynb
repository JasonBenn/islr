# %%
from __future__ import division
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
autos = pd.read_csv('../data/Auto.csv')

# %%
print autos.describe()
autos.ix[:, ['horsepower', 'name']].describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000
#        horsepower        name
# ...

# %%
# Thought this would let me select all rows where horsepower == 150.
# autos[(autos.horsepower == 150), :] # TypeError: 'Series' objects are mutable, thus they cannot be hashed

# Maybe I should try a quantitative column?
# autos[(autos.mpg > 25), :] # TypeError: 'Series' objects are mutable, thus they cannot be hashed. Damn.

# Ah, I need to select a series of rows first, then pass them to #drop.
# autos.drop(autos.ix[10:86]) # ValueError: labels ['mpg' 'cylinders' 'displacement' 'horsepower' 'weight' 'acceleration' 'year' 'origin' 'name'] not contained in axis

# Use #index to get a series of rows, #ix to get a DataFrame.
autos.drop(autos.index[10:86]).describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  321.000000  321.000000    321.000000   321.000000    321.000000
# mean    24.444860    5.370717    187.174455  2933.183801     15.709034
# std      7.899928    1.653486     99.864568   809.638650      2.706441
# min     11.000000    3.000000     68.000000  1649.000000      8.500000
# 25%     18.000000    4.000000    100.000000  2215.000000     14.000000
# 50%     23.900000    4.000000    145.000000  2795.000000     15.500000
# 75%     30.700000    6.000000    250.000000  3504.000000     17.300000
# max     46.600000    8.000000    455.000000  4997.000000     24.800000
#
#              year      origin
# count  321.000000  321.000000
# mean    77.143302    1.598131
# std      3.128202    0.816163
# min     70.000000    1.000000
# 25%     75.000000    1.000000
# 50%     77.000000    1.000000
# 75%     80.000000    2.000000
# max     82.000000    3.000000

# %%
# 9. e) Investigate predictors graphically.
pd.tools.plotting.scatter_matrix(autos, figsize=[18, 18], diagonal="kde")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12369d110>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129de3dd0>]], dtype=object)
